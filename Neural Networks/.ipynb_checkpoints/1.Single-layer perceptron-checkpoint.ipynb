# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#输入数据
X = np.array([[1,3,3],
              [1,4,3],
              [1,1,1],
              [1,0,2]])
#标签
Y = np.array([[1],
              [1],
              [-1],
              [-1]])

#权值初始化，3行1列，取值范围-1到1
W = (np.random.random([3,1])-0.5)*2

plt.scatter(X[:2,1] , X[:2,2] , c = 'b')
plt.scatter(X[2:4,1] , X[2:4,2] , c = 'r')
a = np.array([0,5])
plt.plot(a,-W[0]/W[2]- a * W[1] / W[2] ,'yellow')
plt.show()
print(-W[0]/W[2])
print(-W[1] / W[2])
# Out:
# [0.98501268]
# [0.75347443]

# %%
def update(x , y , lr , epoches):
    #初始化数据
    xMat = np.mat(x)
    yMat = np.mat(y)
    theta = np.mat(np.ones([xMat.shape[1],1]))
    thetaList = theta
    #进行迭代更新theta
    for i in range(epoches):
        theta_gard = xMat * theta
        theta = theta + xMat.T * (yMat - theta_gard) * lr / xMat.shape[0]
        thetaList = np.c_[thetaList , theta]
    return theta,thetaList

# %%
W , thetaList = update(X,Y,0.11,1000)
thetaList.shape
# Out:
# (3, 1001)

# %%
plt.scatter(X[:2,1] , X[:2,2] , c = 'b')
plt.scatter(X[2:4,1] , X[2:4,2] , c = 'r')
a = np.array([0,5])
plt.plot(a,-W[0,0]/W[2,0]- a * W[1,0] / W[2,0] ,'yellow')
plt.show()
print(-W[0,0]/W[2,0])
print(-W[1,0] / W[2,0])
# Out:
# 3.750850810878303
# -0.7504555103495806

# %%
w = thetaList.T
for i in range(1001):
    if i% 10 == 0:
        plt.scatter(X[:2,1] , X[:2,2] , c = 'b')
        plt.scatter(X[2:4,1] , X[2:4,2] , c = 'r')
        a = np.array([0,5])
        plt.plot(a,-w[i,0]/w[i,2]- a * w[i,1] / w[i,2] ,'yellow')
        print(w[i])
        plt.show()
# Out:
# [[1. 1. 1.]]
# [[ 0.16561187  0.37530287 -0.27196524]]
# [[-0.11135481  0.54202031 -0.34252259]]
# [[-0.3061692   0.59978583 -0.32917217]]
# [[-0.45983671  0.612421   -0.28382537]]
# [[-0.5902452   0.60690247 -0.22817057]]
# [[-0.70545128  0.59458186 -0.17113181]]
# [[-0.80930668  0.58019637 -0.11624619]]
# [[-0.90384546  0.56568638 -0.06478818]]
# [[-0.99029861  0.55181266 -0.01709185]]
# [[-1.06952657  0.53884115  0.02689034]]
# [[-1.14220502  0.52683273  0.06735213]]
# [[-1.20890589  0.51576565  0.10453504]]
# [[-1.27013376  0.50558702  0.13868775]]
# [[-1.32634319  0.49623435  0.17004998]]
# [[-1.37794782  0.48764434  0.19884668]]
# [[-1.42532589  0.47975638  0.22528642]]
# [[-1.46882397  0.47251377  0.24956158]]
# [[-1.50875999  0.46586398  0.27184912]]
# [[-1.54542572  0.45975862  0.2923117 ]]
# [[-1.57908899  0.45415317  0.31109871]]
# [[-1.60999567  0.44900671  0.32834732]]
# [[-1.63837152  0.44428166  0.34418351]]
# [[-1.66442375  0.43994353  0.35872293]]
# [[-1.68834266  0.43596064  0.37207177]]
# [[-1.71030293  0.43230389  0.38432752]]
# [[-1.73046495  0.42894658  0.39557969]]
# [[-1.74897597  0.42586418  0.40591045]]
# [[-1.76597118  0.4230342   0.41539527]]
# [[-1.78157472  0.42043595  0.42410341]]
# [[-1.79590053  0.41805046  0.43209846]]
# [[-1.80905326  0.41586031  0.43943883]]
# [[-1.82112895  0.41384951  0.44617812]]
# [[-1.8322158   0.41200336  0.45236555]]
# [[-1.84239479  0.41030839  0.45804632]]
